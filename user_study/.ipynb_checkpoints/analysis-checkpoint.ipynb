# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pre Analysis

# %%
file = './data/pre.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#                    时间戳记  \
# 0  2021-12-6 上午02:57:48
# 1  2021-12-6 下午05:06:18
# 2  2021-12-6 下午05:46:24
# 3  2021-12-6 下午06:22:16
# 4  2021-12-7 下午03:23:25
#
#   1. Have you used VR/MR hardwares before? If yes, please indicate the device in the next question.  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   2.1 Have you used a 3D labelling tool before?  \
# 0                                           Yes
# 1                                            No
# 2                                            No
# 3                                            No
# 4                                            No
#
#   2.2  If you have used a 3D labelling tool before, is it a computer-based tool?  \
# 0                                                Yes
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   3.1 Have you worked in 3D related projects before? e.g. 3D segmentation  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   3.2 If you have worked with a 3D-related project, can you describe what kind of project it is?  \
# 0         The purpose was to label satellite imagery
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  3D segmentation, working with LiDAR Data, GIS ...
#
#   Which mode is the user testing on?
# 0                             Mode 1
# 1                             Mode 1
# 2                             Mode 1
# 3                             Mode 1
# 4                             Mode 2

# %% [markdown]
# ## Post Analysis

# %%
file = './data/post_only.csv'
df = pd.read_csv(file)

# %%
df
# Out:
#                Timestamp  \
# 0    06/12/2021 10:37:36
# 1    06/12/2021 11:09:17
# 2    06/12/2021 11:46:41
# 3    08/12/2021 16:27:34
# 4    08/12/2021 16:30:32
# 5    07/12/2021 08:26:54
# 6    07/12/2021 12:44:04
# 7    07/12/2021 13:50:47
# 8    08/12/2021 17:39:29
# 9    08/12/2021 18:20:50
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ..                   ...
# 868                  NaN
# 869                  NaN
# 870                  NaN
# 871                  NaN
# 872                  NaN
# 873                  NaN
# 874                  NaN
# 875                  NaN
# 876                  NaN
# 877                  NaN
# 878                  NaN
# 879                  NaN
# 880                  NaN
# 881                  NaN
# 882                  NaN
# 883                  NaN
# 884                  NaN
# 885                  NaN
# 886                  NaN
# 887                  NaN
# 888                  NaN
# 889                  NaN
# 890                  NaN
# 891                  NaN
# 892                  NaN
# 893                  NaN
# 894                  NaN
# 895                  NaN
# 896                  NaN
# 897                  NaN
#
#     1. I think that I would like to use this system frequently.  \
# 0                                                Agree
# 1                                              Neutral
# 2                                       Strongly agree
# 3                                       Strongly agree
# 4                                              Neutral
# 5                                              Neutral
# 6                                       Strongly agree
# 7                                       Strongly agree
# 8                                       Strongly agree
# 9                                                Agree
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 875                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
# 884                                                NaN
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# 888                                                NaN
# 889                                                NaN
# 890                                                NaN
# 891                                                NaN
# 892                                                NaN
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#     2. I found the system unnecessarily complex.  \
# 0                                       Disagree
# 1                                       Disagree
# 2                              Strongly disagree
# 3                              Strongly disagree
# 4                                       Disagree
# 5                                       Disagree
# 6                              Strongly disagree
# 7                              Strongly disagree
# 8                              Strongly disagree
# 9                              Strongly disagree
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# ..                                           ...
# 868                                          NaN
# 869                                          NaN
# 870                                          NaN
# 871                                          NaN
# 872                                          NaN
# 873                                          NaN
# 874                                          NaN
# 875                                          NaN
# 876                                          NaN
# 877                                          NaN
# 878                                          NaN
# 879                                          NaN
# 880                                          NaN
# 881                                          NaN
# 882                                          NaN
# 883                                          NaN
# 884                                          NaN
# 885                                          NaN
# 886                                          NaN
# 887                                          NaN
# 888                                          NaN
# 889                                          NaN
# 890                                          NaN
# 891                                          NaN
# 892                                          NaN
# 893                                          NaN
# 894                                          NaN
# 895                                          NaN
# 896                                          NaN
# 897                                          NaN
#
#     3. I thought the system was easy to use  \
# 0                                   Neutral
# 1                                     Agree
# 2                            Strongly agree
# 3                                     Agree
# 4                                     Agree
# 5                                     Agree
# 6                                     Agree
# 7                            Strongly agree
# 8                                     Agree
# 9                                     Agree
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# ..                                      ...
# 868                                     NaN
# 869                                     NaN
# 870                                     NaN
# 871                                     NaN
# 872                                     NaN
# 873                                     NaN
# 874                                     NaN
# 875                                     NaN
# 876                                     NaN
# 877                                     NaN
# 878                                     NaN
# 879                                     NaN
# 880                                     NaN
# 881                                     NaN
# 882                                     NaN
# 883                                     NaN
# 884                                     NaN
# 885                                     NaN
# 886                                     NaN
# 887                                     NaN
# 888                                     NaN
# 889                                     NaN
# 890                                     NaN
# 891                                     NaN
# 892                                     NaN
# 893                                     NaN
# 894                                     NaN
# 895                                     NaN
# 896                                     NaN
# 897                                     NaN
#
#     4. I think that I would need the support of a technical person to be able to use this system.  \
# 0                                              Neutral
# 1                                              Neutral
# 2                                             Disagree
# 3                                             Disagree
# 4                                             Disagree
# 5                                             Disagree
# 6                                             Disagree
# 7                                             Disagree
# 8                                             Disagree
# 9                                                Agree
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 875                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
# 884                                                NaN
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# 888                                                NaN
# 889                                                NaN
# 890                                                NaN
# 891                                                NaN
# 892                                                NaN
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#     5. I found the various functions in this system were well integrated.  \
# 0                                                Agree
# 1                                              Neutral
# 2                                                Agree
# 3                                       Strongly agree
# 4                                       Strongly agree
# 5                                                Agree
# 6                                       Strongly agree
# 7                                                Agree
# 8                                       Strongly agree
# 9                                                Agree
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 875                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
# 884                                                NaN
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# 888                                                NaN
# 889                                                NaN
# 890                                                NaN
# 891                                                NaN
# 892                                                NaN
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#     6. I thought there was too much inconsistency in this system.  \
# 0                                             Disagree
# 1                                             Disagree
# 2                                    Strongly disagree
# 3                                             Disagree
# 4                                             Disagree
# 5                                             Disagree
# 6                                    Strongly disagree
# 7                                             Disagree
# 8                                    Strongly disagree
# 9                                             Disagree
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 875                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
# 884                                                NaN
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# 888                                                NaN
# 889                                                NaN
# 890                                                NaN
# 891                                                NaN
# 892                                                NaN
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#     7. I would imagine that most people would learn to use this system very quickly.  \
# 0                                              Neutral
# 1                                       Strongly agree
# 2                                                Agree
# 3                                       Strongly agree
# 4                                       Strongly agree
# 5                                       Strongly agree
# 6                                                Agree
# 7                                       Strongly agree
# 8                                       Strongly agree
# 9                                                Agree
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 875                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
# 884                                                NaN
# 885                                                NaN
# 886                                                NaN
# 887  7. I would imagine that most people would lear...
# 888                                            Neutral
# 889                                     Strongly agree
# 890                                              Agree
# 891                                     Strongly agree
# 892                                     Strongly agree
# 893                                     Strongly agree
# 894                                              Agree
# 895                                     Strongly agree
# 896                                     Strongly agree
# 897                                              Agree
#
#     8. I found the system very cumbersome to use.  \
# 0                                        Disagree
# 1                                        Disagree
# 2                               Strongly disagree
# 3                                        Disagree
# 4                               Strongly disagree
# 5                                        Disagree
# 6                               Strongly disagree
# 7                               Strongly disagree
# 8                                        Disagree
# 9                                        Disagree
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ..                                            ...
# 868                                           NaN
# 869                                           NaN
# 870                                           NaN
# 871                                           NaN
# 872                                           NaN
# 873                                           NaN
# 874                                           NaN
# 875                                           NaN
# 876                                           NaN
# 877                                           NaN
# 878                                           NaN
# 879                                           NaN
# 880                                           NaN
# 881                                           NaN
# 882                                           NaN
# 883                                           NaN
# 884                                           NaN
# 885                                           NaN
# 886                                           NaN
# 887                                           NaN
# 888                                           NaN
# 889                                           NaN
# 890                                           NaN
# 891                                           NaN
# 892                                           NaN
# 893                                           NaN
# 894                                           NaN
# 895                                           NaN
# 896                                           NaN
# 897                                           NaN
#
#     9. I felt very confident using the system.  \
# 0                                      Neutral
# 1                                      Neutral
# 2                               Strongly agree
# 3                                        Agree
# 4                                        Agree
# 5                                        Agree
# 6                               Strongly agree
# 7                               Strongly agree
# 8                                        Agree
# 9                                      Neutral
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# ..                                         ...
# 868                                        NaN
# 869                                        NaN
# 870                                        NaN
# 871                                        NaN
# 872                                        NaN
# 873                                        NaN
# 874                                        NaN
# 875                                        NaN
# 876                                        NaN
# 877                                        NaN
# 878                                        NaN
# 879                                        NaN
# 880                                        NaN
# 881                                        NaN
# 882                                        NaN
# 883                                        NaN
# 884                                        NaN
# 885                                        NaN
# 886                                        NaN
# 887                                        NaN
# 888                                        NaN
# 889                                        NaN
# 890                                        NaN
# 891                                        NaN
# 892                                        NaN
# 893                                        NaN
# 894                                        NaN
# 895                                        NaN
# 896                                        NaN
# 897                                        NaN
#
#     10. I needed to learn a lot of things before I could get going with this system.  \
# 0                                             Disagree
# 1                                              Neutral
# 2                                             Disagree
# 3                                             Disagree
# 4                                    Strongly disagree
# 5                                             Disagree
# 6                                    Strongly disagree
# 7                                    Strongly disagree
# 8                                              Neutral
# 9                                    Strongly disagree
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 868                                                NaN
# 869                                                NaN
# 870                                                NaN
# 871                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 875                                                NaN
# 876                                                NaN
# 877                                                NaN
# 878                                                NaN
# 879                                                NaN
# 880                                                NaN
# 881                                                NaN
# 882                                                NaN
# 883                                                NaN
# 884                                                NaN
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# 888                                                NaN
# 889                                                NaN
# 890                                                NaN
# 891                                                NaN
# 892                                                NaN
# 893                                                NaN
# 894                                                NaN
# 895                                                NaN
# 896                                                NaN
# 897                                                NaN
#
#     Which mode is the user testing?
# 0                            Mode 1
# 1                            Mode 1
# 2                            Mode 1
# 3                            Mode 1
# 4                            Mode 1
# 5                            Mode 2
# 6                            Mode 2
# 7                            Mode 2
# 8                            Mode 2
# 9                            Mode 2
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                              NaN
# 27                              NaN
# 28                              NaN
# 29                              NaN
# ..                              ...
# 868                             NaN
# 869                             NaN
# 870                             NaN
# 871                             NaN
# 872                             NaN
# 873                             NaN
# 874                             NaN
# 875                             NaN
# 876                             NaN
# 877                             NaN
# 878                             NaN
# 879                             NaN
# 880                             NaN
# 881                             NaN
# 882                             NaN
# 883                             NaN
# 884                             NaN
# 885                             NaN
# 886                             NaN
# 887                             NaN
# 888                             NaN
# 889                             NaN
# 890                             NaN
# 891                             NaN
# 892                             NaN
# 893                             NaN
# 894                             NaN
# 895                             NaN
# 896                             NaN
# 897                             NaN
#
# [898 rows x 12 columns]

# %%
data = np.genfromtxt(file, skip_header=1, dtype=str, delimiter=',')[:10, :]

# %%
data
# Out:
# array([['06/12/2021 10:37:36', 'Agree', 'Disagree', 'Neutral', 'Neutral',
#         'Agree', 'Disagree', 'Neutral', 'Disagree', 'Neutral',
#         'Disagree', 'Mode 1'],
#        ['06/12/2021 11:09:17', 'Neutral', 'Disagree', 'Agree', 'Neutral',
#         'Neutral', 'Disagree', 'Strongly agree', 'Disagree', 'Neutral',
#         'Neutral', 'Mode 1'],
#        ['06/12/2021 11:46:41', 'Strongly agree', 'Strongly disagree',
#         'Strongly agree', 'Disagree', 'Agree', 'Strongly disagree',
#         'Agree', 'Strongly disagree', 'Strongly agree', 'Disagree',
#         'Mode 1'],
#        ['08/12/2021 16:27:34', 'Strongly agree', 'Strongly disagree',
#         'Agree', 'Disagree', 'Strongly agree', 'Disagree',
#         'Strongly agree', 'Disagree', 'Agree', 'Disagree', 'Mode 1'],
#        ['08/12/2021 16:30:32', 'Neutral', 'Disagree', 'Agree',
#         'Disagree', 'Strongly agree', 'Disagree', 'Strongly agree',
#         'Strongly disagree', 'Agree', 'Strongly disagree', 'Mode 1'],
#        ['07/12/2021 08:26:54', 'Neutral', 'Disagree', 'Agree',
#         'Disagree', 'Agree', 'Disagree', 'Strongly agree', 'Disagree',
#         'Agree', 'Disagree', 'Mode 2'],
#        ['07/12/2021 12:44:04', 'Strongly agree', 'Strongly disagree',
#         'Agree', 'Disagree', 'Strongly agree', 'Strongly disagree',
#         'Agree', 'Strongly disagree', 'Strongly agree',
#         'Strongly disagree', 'Mode 2'],
#        ['07/12/2021 13:50:47', 'Strongly agree', 'Strongly disagree',
#         'Strongly agree', 'Disagree', 'Agree', 'Disagree',
#         'Strongly agree', 'Strongly disagree', 'Strongly agree',
#         'Strongly disagree', 'Mode 2'],
#        ['08/12/2021 17:39:29', 'Strongly agree', 'Strongly disagree',
#         'Agree', 'Disagree', 'Strongly agree', 'Strongly disagree',
#         'Strongly agree', 'Disagree', 'Agree', 'Neutral', 'Mode 2'],
#        ['08/12/2021 18:20:50', 'Agree', 'Strongly disagree', 'Agree',
#         'Agree', 'Agree', 'Disagree', 'Agree', 'Disagree', 'Neutral',
#         'Strongly disagree', 'Mode 2']], dtype='<U80')

# %%
values = {"Strongly disagree": 1, "Disagree": 2, "Neutral": 3, "Agree": 4, "Strongly agree": 5}
modes = {'Mode 1': 1, "Mode 2": 2}

# %%
newdata = np.zeros((len(data), data.shape[1]-1))
for i in range(len(data)):
    for j in range(data.shape[1]):
        if data[i, j].startswith('0'):
            continue
        if data[i, j].startswith('M'):
            newdata[i, j-1] = modes[data[i, j]]
            continue
        newdata[i, j-1] = values[data[i, j]]-1 if j in [1, 3, 5, 7, 9] else 5-values[data[i, j]]

# %%
newdata = newdata[1:, :]

# %%
scores = newdata[:, :-1]
# per person
sus = np.sum(scores, axis=1)*2.5
np.histogram(sus, bins=[55, 65, 75, 85, 95])
# Out:
# (array([0, 2, 2, 5]), array([55, 65, 75, 85, 95]))

# %%
scores_mode1 = newdata[newdata[:, -1]==1.][:, :-1]
# per person
sus = np.sum(scores_mode1, axis=1)*2.5
np.histogram(sus, bins=[55, 65, 75, 85, 95])
sus.mean()
# Out:
# 80.625

# %%
sus
# Out:
# array([65. , 90. , 85. , 82.5])

# %%
scores_mode2 = newdata[newdata[:, -1]==2.][:, :-1]
# per person
sus = np.sum(scores_mode2, axis=1)*2.5
np.histogram(sus, bins=[55, 65, 75, 85, 95])
sus.mean()
# Out:
# 83.5

# %% [markdown]
# ## Total
# Usability scores are high and people found the usability of the applications are good.
# Two modes achieve similar usability score and differences mainly lie in specific comments.
#
# ### Dynamic
# 4 participants
# - Easy to use, good immersive experience.
# - But better to provide more fine-level brush thickness options
#
# ### Static
# 5 participants
#
# - Complex controlls, reminders are needed
# - Some people hope to have a more immersive experience (e.g. walk into the room) since it's VR device.
#
# ## From user's background
# - used VR before: interesting VR experience but one person thinks it severs no purpose
# - used 3D labelling tool before: only one person (tried mode 2) found controller more complex than previous tools
# - worked on 3D projects before: 2 persons, one said could be used to generate ground truth efficiently, the another one said it's hard to label, improvements needed
#
# ## Problems with user study:
# only 3 users have experience in 3D projects (only 1 user used 3D labelling tool before) and all of them tried static mode. 2 of them mentioned (including the one user used 3D labelling tool before) it's hard to controll.
